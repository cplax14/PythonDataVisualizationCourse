# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import matplotlib as plt

# %%
dframe = pd.read_excel('jobpartitionperfanalysis.xlsx','Sheet1')
dframe
# Out:
#        rundate  CountStudiosWTrans  TotalTrans  Duration JobPartition  \
# 0   2015-06-01                 989       28496       786     WEST0112
# 1   2015-06-01                 991       24235       726     WEST0111
# 2   2015-06-01                 142       39619       634     WEST0107
# 3   2015-06-01                 326       28038       597     EAST0101
# 4   2015-06-01                 620       23203       595     WEST0105
# 5   2015-06-01                 450       23092       593     WEST0106
# 6   2015-06-01                 794       30289       586     WEST0109
# 7   2015-06-01                 948       19252       575     EAST0110
# 8   2015-06-01                 568       18898       572     WEST0103
# 9   2015-06-01                 522       24971       563     EAST0105
# 10  2015-06-01                 406       23696       539     WEST0108
# 11  2015-06-01                 721       25970       535     EAST0107
# ...

# %%
dframe.describe()
# Out:
#        CountStudiosWTrans    TotalTrans    Duration  StdDevNumTrans  \
# count          154.000000    154.000000  154.000000      154.000000
# mean           432.746753   5684.506494  187.675325       49.334524
# std            197.832786   7501.878323  155.893037      126.907326
# min             77.000000    982.000000   49.000000        4.439701
# 25%            306.500000   2033.000000  108.250000       10.576555
# 50%            414.500000   3134.000000  134.000000       16.560222
# 75%            532.500000   3874.750000  163.000000       43.635379
# max            991.000000  39619.000000  786.000000     1332.724143
#
#        TransPerStudioWTrans  DayOfMonthNumber  TotalCountStudios  \
# count            154.000000        154.000000         154.000000
# mean              15.388649         14.285714        2303.136364
# std               29.105005         13.690183         848.303637
# min                2.948132          1.000000        1281.000000
# ...

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 0 to 153
# Data columns (total 11 columns):
# rundate                     154 non-null datetime64[ns]
# CountStudiosWTrans          154 non-null int64
# TotalTrans                  154 non-null int64
# Duration                    154 non-null int64
# JobPartition                154 non-null object
# StdDevNumTrans              154 non-null float64
# TransPerStudioWTrans        154 non-null float64
# DayOfMonthNumber            154 non-null int64
# TotalCountStudios           154 non-null int64
# TransPerTotalStudioCount    154 non-null float64
# StudiosWNoTrans             154 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(1)
# memory usage: 14.4+ KB
