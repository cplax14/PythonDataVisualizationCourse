# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
xlsfile = pd.ExcelFile('C:\Users\joshua.moore\Documents\Projects\Job Partition Rebalance 6-30-2015\July 1st Autopay Script Duration Analysis 7-1-2015.xlsx')

# %%
dframe = xlsfile.parse('Sheet1')
dframe
# Out:
#     CountStudios  TotalTrans  Duration JobPartition  StdDevNumTrans  \
# 0            315       27067       627     EAST0101      332.280439
# 1            308       14645       342     EAST0108      191.998514
# 2            460        9211       326     EAST0111       49.079677
# 3            421        9151       287     EAST0114       52.042412
# 4            127       22800       489     WEST0101      671.309671
# 5            402       15737       485     WEST0103       90.064713
# 6            407       19253       469     WEST0105      149.377399
# 7            697       10461       392     WEST0113       30.970295
# 8            405       16395       470     EAST0102      135.555584
# 9            435       11936       211     EAST0109      124.410713
# 10           415       14430       415     WEST0104       84.862855
# 11           251       18845       468     WEST0106      165.085061
# 12           513       16248       379     WEST0111       83.818878
# ...

# %%
sns.lmplot('TotalTrans','Duration',dframe)

# %%
sns.lmplot('TotalTrans','Duration',dframe,hue='TransPerStudio')
